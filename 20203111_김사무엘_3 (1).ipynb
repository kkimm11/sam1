# %% [markdown]
# #<이미지의 테두리만 추출하는 코드>
#
# ## ****OpenCV****함수 활용을 위해 **import cv2** 활용
#
# ##colab은 cv2.imshow 옵션이 비활성화 되어있기 때문에 ~to crush라는 오류가 생긴다.
#
# ##*따라서 google.colab.patches라는 라이브러리를 자체적으로 제작한다.
#
# ##**from google.colab.patches import cv2_imshow**를 부가로 입력한다.
#
# ```import cv2```
# ```from google.colab.patches import cv2_imshow1```

# %%
#OpenCV함수를 활용하기 위해 import cv2를 입력한다,
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# #1. 이미지를 **fname**으로 설정해준다
# #2.**cv2.imread명령어**를 이용하여 영상파일을 불러온다
# #3. **cv2_imshow**를 이용하여 img파일을 출력
# ```

# %%
fname = '/cat1.jpg'
img = cv2.imread(fname)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=570x474>

# %% [markdown]
# #**threshold1** : 다른 엣지와의 인접 부분(엣지가 되기 쉬운 부분)에 있어 엣지인지 아닌지를 판단하는 임계값
# #**threshold2** : 엣지인지 아닌지를 판단하는 임계값
# ###*두개의 값을 줄일수록 엣지의 양이 많아진다.*
#
# ---
# #테두리만 출력하는파일을 method_canny로 설정하고 *cv2.Canny**함수를 이용하여 테두리만 출력한다.
# ```method_canny=cv2.Canny(img,threshold1,threshold2)```
#
#
#
# #마지막으로 **cv_imshow**함수를 이용해 출력한다.

# %%
threshold1 = 50
threshold2 = 200
method_canny=cv2.Canny(img,threshold1,threshold2)
cv2_imshow(method_canny)
# Out:
# <PIL.Image.Image image mode=L size=570x474>
